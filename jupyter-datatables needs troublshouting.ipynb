# %%
import numpy as np
import pandas as pd

from jupyter_datatables import init_datatables_mode

# %%
# %load_ext jupyter_require

# %requirejs d3 https://d3js.org/d3.v5.min
# Out:
# The jupyter_require extension is already loaded. To reload it, use:
#   %reload_ext jupyter_require

# %%
sales = pd.read_csv('./data/Demo_sales_data.csv')

# %%
init_datatables_mode()

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08/11/2021  11/11/2021    Second Class
# 1          2  CA-2016-152156  08/11/2021  11/11/2021    Second Class
# 2          3  CA-2016-138688  12/06/2021  16/06/2021    Second Class
# 3         14  CA-2016-161389  05/12/2021  10/12/2021  Standard Class
# 4         22  CA-2016-137330  09/12/2021  13/12/2021  Standard Class
# ...      ...             ...         ...         ...             ...
# 2582    9979  US-2016-103674  06/12/2021  10/12/2021  Standard Class
# 2583    9980  US-2016-103674  06/12/2021  10/12/2021  Standard Class
# 2584    9983  US-2016-157728  22/09/2021  28/09/2021  Standard Class
# 2585    9984  US-2016-157728  22/09/2021  28/09/2021  Standard Class
# 2586    9987  CA-2016-125794  29/09/2021  03/10/2021  Standard Class
#
#      Customer ID    Customer Name      Segment        Country          City  \
# 0       CG-12520      Claire Gute     Consumer  United States     Henderson
# 1       CG-12520      Claire Gute     Consumer  United States     Henderson
# 2       DV-13045  Darrin Van Huff    Corporate  United States   Los Angeles
# 3       IM-15070     Irene Maddox     Consumer  United States       Seattle
# 4       KB-16585        Ken Black    Corporate  United States       Fremont
# ...          ...              ...          ...            ...           ...
# 2582    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 2583    AP-10720       Anne Pryor  Home Office  United States   Los Angeles
# 2584    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 2585    RC-19960       Ryan Crowe     Consumer  United States  Grand Rapids
# 2586    ML-17410     Maris LaWare     Consumer  United States   Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0     ...       42420    South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420    South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036     West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       98103     West  OFF-BI-10003656  Office Supplies      Binders
# 4     ...       68025  Central  OFF-AR-10000246  Office Supplies          Art
# ...   ...         ...      ...              ...              ...          ...
# 2582  ...       90032     West  OFF-BI-10003727  Office Supplies      Binders
# 2583  ...       90032     West  OFF-BI-10002026  Office Supplies      Binders
# 2584  ...       49505  Central  OFF-PA-10002195  Office Supplies        Paper
# 2585  ...       49505  Central  TEC-PH-10001305       Technology       Phones
# 2586  ...       90008     West  TEC-AC-10003399       Technology  Accessories
#
#                                            Product Name   Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.96         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.62         2
# 3           Fellowes PB200 Plastic Comb Binding Machine  407.98         3
# 4                                            Newell 318   19.46         7
# ...                                                 ...     ...       ...
# 2582  Avery Durable Slant Ring Binders With Label Ho...   13.38         4
# 2583                  Ibico Recycled Linen-Style Covers  437.47        14
# 2584  RSVP Cards & Envelopes, Blank White, 8-1/2" X ...   35.56         7
# 2585                   Panasonic KX TS208W Corded phone   97.98         2
# 2586  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.24         1
#
#       Discount  Profit
# 0          0.0   41.91
# 1          0.0  219.58
# 2          0.0    6.87
# 3          0.2  132.59
# 4          0.0    5.06
# ...        ...     ...
# 2582       0.2    4.68
# 2583       0.2  153.12
# 2584       0.0   16.71
# 2585       0.0   27.43
# 2586       0.0   15.22
#
# [2587 rows x 21 columns]

# %%
dft = pd.DataFrame({'A': np.random.rand(5),
                    'B': [1, 1, 3, 2, 1],
                    'C': 'This is a very long sentence that should automatically be trimmed',
                    'D': [pd.Timestamp('20010101'), pd.Timestamp('20010102'), pd.Timestamp('20010103'), pd.Timestamp('20010104'), pd.Timestamp('20010105')],
                    'E': pd.Series([1.0] * 5).astype('float32'),
                    'F': [False, True, False, False, True],
                   })

dft.D = dft.D.apply(pd.to_datetime)
dft.set_index('D', inplace=True)

# %%
dft
# Out:
#                    A  B                                                  C  \
# D
# 2001-01-01  0.602666  1  This is a very long sentence that should autom...
# 2001-01-02  0.545090  1  This is a very long sentence that should autom...
# 2001-01-03  0.216862  3  This is a very long sentence that should autom...
# 2001-01-04  0.793792  2  This is a very long sentence that should autom...
# 2001-01-05  0.652753  1  This is a very long sentence that should autom...
#
#               E      F
# D
# 2001-01-01  1.0  False
# 2001-01-02  1.0   True
# 2001-01-03  1.0  False
# 2001-01-04  1.0  False
# 2001-01-05  1.0   True
